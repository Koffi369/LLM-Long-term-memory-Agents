# %%
InvalidDimensionException: Embedding dimension 1024 does not match collection dimensionality 384
# Out:
# /home/koffi369/Desktop/SKOLTECH/LLM_Reseach/Memory_agent

# %%
! python src/chat.py
# Out:
#   File "/home/koffi369/Desktop/SKOLTECH/LLM_Reseach/Memory_agent/src/chat.py", line 60
#     llm = nous-hermes-llama2-13b.Q4_0.gguf
#                               ^
# SyntaxError: invalid decimal literal

# %%
# !pip  install -r  requirements.txt
# Out:
# Collecting aiohttp==3.8.5 (from -r requirements.txt (line 1))
#   Using cached aiohttp-3.8.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Collecting aiosignal==1.3.1 (from -r requirements.txt (line 2))
#   Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting anyio==4.0.0 (from -r requirements.txt (line 3))
#   Using cached anyio-4.0.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting async-timeout==4.0.3 (from -r requirements.txt (line 4))
#   Using cached async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: attrs==23.1.0 in /home/koffi369/anaconda3/envs/memory_agent/lib/python3.11/site-packages (from -r requirements.txt (line 5)) (23.1.0)
# Collecting backoff==2.2.1 (from -r requirements.txt (line 6))
#   Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Collecting bcrypt==4.0.1 (from -r requirements.txt (line 7))
#   Using cached bcrypt-4.0.1-cp36-abi3-manylinux_2_28_x86_64.whl (593 kB)
# Requirement already satisfied: beautifulsoup4==4.12.2 in /home/koffi369/anaconda3/envs/memory_agent/lib/python3.11/site-packages (from -r requirements.txt (line 8)) (4.12.2)
# Collecting bs4==0.0.1 (from -r requirements.txt (line 9))
#   Using cached bs4-0.0.1.tar.gz (1.1 kB)
#   Preparing metadata (setup.py) ... done
# Collecting certifi==2023.7.22 (from -r requirements.txt (line 10))
#   Using cached certifi-2023.7.22-py3-none-any.whl.metadata (2.2 kB)
# Collecting charset-normalizer==3.2.0 (from -r requirements.txt (line 11))
#   Using cached charset_normalizer-3.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (31 kB)
# Collecting chroma-hnswlib==0.7.3 (from -r requirements.txt (line 12))
#   Using cached chroma_hnswlib-0.7.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (252 bytes)
# Collecting chromadb==0.4.10 (from -r requirements.txt (line 13))
#   Using cached chromadb-0.4.10-py3-none-any.whl.metadata (7.0 kB)
# Collecting click==8.1.7 (from -r requirements.txt (line 14))
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting colorama==0.4.6 (from -r requirements.txt (line 15))
#   Using cached colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting coloredlogs==15.0.1 (from -r requirements.txt (line 16))
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Collecting dataclasses-json==0.5.14 (from -r requirements.txt (line 17))
#   Using cached dataclasses_json-0.5.14-py3-none-any.whl.metadata (22 kB)
# Collecting diskcache==5.6.3 (from -r requirements.txt (line 18))
#   Using cached diskcache-5.6.3-py3-none-any.whl.metadata (20 kB)
# Collecting exceptiongroup==1.1.3 (from -r requirements.txt (line 19))
#   Using cached exceptiongroup-1.1.3-py3-none-any.whl.metadata (6.1 kB)
# Collecting fastapi==0.99.1 (from -r requirements.txt (line 20))
#   Using cached fastapi-0.99.1-py3-none-any.whl.metadata (23 kB)
# Collecting filelock==3.12.4 (from -r requirements.txt (line 21))
#   Using cached filelock-3.12.4-py3-none-any.whl.metadata (2.8 kB)
# Collecting flatbuffers==23.5.26 (from -r requirements.txt (line 22))
#   Using cached flatbuffers-23.5.26-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting frozenlist==1.4.0 (from -r requirements.txt (line 23))
#   Using cached frozenlist-1.4.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.2 kB)
# Collecting fsspec==2023.9.1 (from -r requirements.txt (line 24))
#   Using cached fsspec-2023.9.1-py3-none-any.whl.metadata (6.7 kB)
# Collecting google==3.0.0 (from -r requirements.txt (line 25))
#   Using cached google-3.0.0-py2.py3-none-any.whl (45 kB)
# Collecting googlemaps==4.10.0 (from -r requirements.txt (line 26))
#   Using cached googlemaps-4.10.0.tar.gz (33 kB)
#   Preparing metadata (setup.py) ... done
# Collecting gpt4all==2.0.2 (from -r requirements.txt (line 27))
#   Using cached gpt4all-2.0.2-py3-none-manylinux1_x86_64.whl.metadata (892 bytes)
# Collecting greenlet==2.0.2 (from -r requirements.txt (line 28))
#   Using cached greenlet-2.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (618 kB)
# Collecting h11==0.14.0 (from -r requirements.txt (line 29))
#   Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Collecting httptools==0.6.0 (from -r requirements.txt (line 30))
#   Using cached httptools-0.6.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Collecting huggingface-hub==0.16.4 (from -r requirements.txt (line 31))
#   Using cached huggingface_hub-0.16.4-py3-none-any.whl.metadata (12 kB)
# Collecting humanfriendly==10.0 (from -r requirements.txt (line 32))
#   Using cached humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Requirement already satisfied: idna==3.4 in /home/koffi369/anaconda3/envs/memory_agent/lib/python3.11/site-packages (from -r requirements.txt (line 33)) (3.4)
# Collecting importlib-resources==6.0.1 (from -r requirements.txt (line 34))
#   Using cached importlib_resources-6.0.1-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: Jinja2==3.1.2 in /home/koffi369/anaconda3/envs/memory_agent/lib/python3.11/site-packages (from -r requirements.txt (line 35)) (3.1.2)
# Collecting joblib==1.3.2 (from -r requirements.txt (line 36))
#   Using cached joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting langchain==0.0.295 (from -r requirements.txt (line 37))
#   Using cached langchain-0.0.295-py3-none-any.whl.metadata (14 kB)
# Collecting langsmith==0.0.38 (from -r requirements.txt (line 38))
#   Using cached langsmith-0.0.38-py3-none-any.whl.metadata (10 kB)
# Collecting llama_cpp_python==0.2.11 (from -r requirements.txt (line 39))
#   Using cached llama_cpp_python-0.2.11.tar.gz (3.6 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: MarkupSafe==2.1.3 in /home/koffi369/anaconda3/envs/memory_agent/lib/python3.11/site-packages (from -r requirements.txt (line 40)) (2.1.3)
# Collecting marshmallow==3.20.1 (from -r requirements.txt (line 41))
#   Using cached marshmallow-3.20.1-py3-none-any.whl.metadata (7.8 kB)
# Collecting monotonic==1.6 (from -r requirements.txt (line 42))
#   Using cached monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Requirement already satisfied: mpmath==1.3.0 in /home/koffi369/anaconda3/envs/memory_agent/lib/python3.11/site-packages (from -r requirements.txt (line 43)) (1.3.0)
# Collecting multidict==6.0.4 (from -r requirements.txt (line 44))
#   Using cached multidict-6.0.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (117 kB)
# Collecting mypy-extensions==1.0.0 (from -r requirements.txt (line 45))
#   Using cached mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Collecting networkx==3.1 (from -r requirements.txt (line 46))
#   Using cached networkx-3.1-py3-none-any.whl (2.1 MB)
# Collecting nltk==3.8.1 (from -r requirements.txt (line 47))
#   Using cached nltk-3.8.1-py3-none-any.whl (1.5 MB)
# Collecting numexpr==2.8.6 (from -r requirements.txt (line 48))
#   Using cached numexpr-2.8.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.0 kB)
# Collecting numpy==1.26.0 (from -r requirements.txt (line 49))
#   Using cached numpy-1.26.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (58 kB)
# Collecting onnxruntime==1.15.1 (from -r requirements.txt (line 50))
#   Using cached onnxruntime-1.15.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Requirement already satisfied: overrides==7.4.0 in /home/koffi369/anaconda3/envs/memory_agent/lib/python3.11/site-packages (from -r requirements.txt (line 51)) (7.4.0)
# Requirement already satisfied: packaging==23.1 in /home/koffi369/anaconda3/envs/memory_agent/lib/python3.11/site-packages (from -r requirements.txt (line 52)) (23.1)
# Collecting pandas==2.1.1 (from -r requirements.txt (line 53))
#   Using cached pandas-2.1.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: Pillow==9.3.0 in /home/koffi369/anaconda3/envs/memory_agent/lib/python3.11/site-packages (from -r requirements.txt (line 54)) (9.3.0)
# Collecting posthog==3.0.2 (from -r requirements.txt (line 55))
#   Using cached posthog-3.0.2-py2.py3-none-any.whl.metadata (2.0 kB)
# Collecting protobuf==4.24.3 (from -r requirements.txt (line 56))
#   Using cached protobuf-4.24.3-cp37-abi3-manylinux2014_x86_64.whl.metadata (540 bytes)
# Collecting pulsar-client==3.3.0 (from -r requirements.txt (line 57))
#   Using cached pulsar_client-3.3.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.0 kB)
# Collecting pydantic==1.10.12 (from -r requirements.txt (line 58))
#   Using cached pydantic-1.10.12-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (149 kB)
# Collecting PyPika==0.48.9 (from -r requirements.txt (line 59))
#   Using cached PyPika-0.48.9-py2.py3-none-any.whl
# Collecting pyreadline3==3.4.1 (from -r requirements.txt (line 60))
#   Using cached pyreadline3-3.4.1-py3-none-any.whl (95 kB)
# Requirement already satisfied: python-dateutil==2.8.2 in /home/koffi369/anaconda3/envs/memory_agent/lib/python3.11/site-packages (from -r requirements.txt (line 61)) (2.8.2)
# Collecting python-dotenv==1.0.0 (from -r requirements.txt (line 62))
#   Using cached python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: pytz==2023.3.post1 in /home/koffi369/anaconda3/envs/memory_agent/lib/python3.11/site-packages (from -r requirements.txt (line 63)) (2023.3.post1)
# Requirement already satisfied: PyYAML==6.0.1 in /home/koffi369/anaconda3/envs/memory_agent/lib/python3.11/site-packages (from -r requirements.txt (line 64)) (6.0.1)
# Collecting regex==2023.8.8 (from -r requirements.txt (line 65))
#   Using cached regex-2023.8.8-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
# Requirement already satisfied: requests==2.31.0 in /home/koffi369/anaconda3/envs/memory_agent/lib/python3.11/site-packages (from -r requirements.txt (line 66)) (2.31.0)
# Collecting safetensors==0.3.3 (from -r requirements.txt (line 67))
#   Using cached safetensors-0.3.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.7 kB)
# Collecting scikit-learn==1.3.1 (from -r requirements.txt (line 68))
#   Using cached scikit_learn-1.3.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting scipy==1.11.2 (from -r requirements.txt (line 69))
#   Using cached scipy-1.11.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (59 kB)
# Collecting sentencepiece==0.1.99 (from -r requirements.txt (line 70))
#   Using cached sentencepiece-0.1.99-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
# Requirement already satisfied: six==1.16.0 in /home/koffi369/anaconda3/envs/memory_agent/lib/python3.11/site-packages (from -r requirements.txt (line 71)) (1.16.0)
# Collecting sniffio==1.3.0 (from -r requirements.txt (line 72))
#   Using cached sniffio-1.3.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: soupsieve==2.5 in /home/koffi369/anaconda3/envs/memory_agent/lib/python3.11/site-packages (from -r requirements.txt (line 73)) (2.5)
# Collecting SQLAlchemy==2.0.21 (from -r requirements.txt (line 74))
#   Using cached SQLAlchemy-2.0.21-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.4 kB)
# Collecting starlette==0.27.0 (from -r requirements.txt (line 75))
#   Using cached starlette-0.27.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: sympy==1.12 in /home/koffi369/anaconda3/envs/memory_agent/lib/python3.11/site-packages (from -r requirements.txt (line 76)) (1.12)
# Collecting tenacity==8.2.3 (from -r requirements.txt (line 77))
#   Using cached tenacity-8.2.3-py3-none-any.whl.metadata (1.0 kB)
# Collecting termcolor==2.3.0 (from -r requirements.txt (line 78))
#   Using cached termcolor-2.3.0-py3-none-any.whl (6.9 kB)
# Collecting threadpoolctl==3.2.0 (from -r requirements.txt (line 79))
#   Using cached threadpoolctl-3.2.0-py3-none-any.whl.metadata (10.0 kB)
# Collecting tokenizers==0.13.3 (from -r requirements.txt (line 80))
#   Using cached tokenizers-0.13.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
# Requirement already satisfied: torch==2.0.1+cu117 in /home/koffi369/anaconda3/envs/memory_agent/lib/python3.11/site-packages (from -r requirements.txt (line 81)) (2.0.1+cu117)
# Requirement already satisfied: torchaudio==2.0.2+cu117 in /home/koffi369/anaconda3/envs/memory_agent/lib/python3.11/site-packages (from -r requirements.txt (line 82)) (2.0.2+cu117)
# Requirement already satisfied: torchvision==0.15.2+cu117 in /home/koffi369/anaconda3/envs/memory_agent/lib/python3.11/site-packages (from -r requirements.txt (line 83)) (0.15.2+cu117)
# Collecting tqdm==4.66.1 (from -r requirements.txt (line 84))
#   Using cached tqdm-4.66.1-py3-none-any.whl.metadata (57 kB)
# Collecting transformers==4.33.2 (from -r requirements.txt (line 85))
#   Downloading transformers-4.33.2-py3-none-any.whl.metadata (119 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.9/119.9 kB 294.1 kB/s eta 0:00:001m260.7 kB/s eta 0:00:01
# Collecting typing-inspect==0.9.0 (from -r requirements.txt (line 86))
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting typing_extensions==4.8.0 (from -r requirements.txt (line 87))
#   Downloading typing_extensions-4.8.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting tzdata==2023.3 (from -r requirements.txt (line 88))
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 1.5 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting urllib3==2.0.4 (from -r requirements.txt (line 89))
#   Downloading urllib3-2.0.4-py3-none-any.whl.metadata (6.6 kB)
# Collecting uvicorn==0.23.2 (from -r requirements.txt (line 90))
#   Downloading uvicorn-0.23.2-py3-none-any.whl.metadata (6.2 kB)
# Collecting watchfiles==0.20.0 (from -r requirements.txt (line 91))
#   Downloading watchfiles-0.20.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting websockets==11.0.3 (from -r requirements.txt (line 92))
#   Downloading websockets-11.0.3-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.6/130.6 kB 1.5 MB/s eta 0:00:003.1 MB/s eta 0:00:01
# Collecting xformers==0.0.21 (from -r requirements.txt (line 93))
#   Downloading xformers-0.0.21-cp311-cp311-manylinux2014_x86_64.whl.metadata (1.0 kB)
# Collecting yarl==1.9.2 (from -r requirements.txt (line 94))
#   Downloading yarl-1.9.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (282 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 282.8/282.8 kB 1.9 MB/s eta 0:00:002.4 MB/s eta 0:00:01
# Requirement already satisfied: triton==2.0.0 in /home/koffi369/anaconda3/envs/memory_agent/lib/python3.11/site-packages (from torch==2.0.1+cu117->-r requirements.txt (line 81)) (2.0.0)
# Requirement already satisfied: cmake in /home/koffi369/anaconda3/envs/memory_agent/lib/python3.11/site-packages (from triton==2.0.0->torch==2.0.1+cu117->-r requirements.txt (line 81)) (3.25.0)
# Requirement already satisfied: lit in /home/koffi369/anaconda3/envs/memory_agent/lib/python3.11/site-packages (from triton==2.0.0->torch==2.0.1+cu117->-r requirements.txt (line 81)) (15.0.7)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.18.3->chromadb==0.4.10->-r requirements.txt (line 13))
#   Downloading uvloop-0.19.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Downloading aiohttp-3.8.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 2.5 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Downloading anyio-4.0.0-py3-none-any.whl (83 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.1/83.1 kB 2.0 MB/s eta 0:00:000:00:01
# Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Downloading certifi-2023.7.22-py3-none-any.whl (158 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 4.1 MB/s eta 0:00:004.6 MB/s eta 0:00:01
# Downloading charset_normalizer-3.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (199 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.6/199.6 kB 2.6 MB/s eta 0:00:003.0 MB/s eta 0:00:01
# Downloading chroma_hnswlib-0.7.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 3.7 MB/s eta 0:00:000:00:01m eta 0:00:01
# Downloading chromadb-0.4.10-py3-none-any.whl (422 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 422.4/422.4 kB 3.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading click-8.1.7-py3-none-any.whl (97 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 kB 23.4 MB/s eta 0:00:00
# Downloading dataclasses_json-0.5.14-py3-none-any.whl (26 kB)
# Using cached diskcache-5.6.3-py3-none-any.whl (45 kB)
# Downloading exceptiongroup-1.1.3-py3-none-any.whl (14 kB)
# Downloading fastapi-0.99.1-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 1.4 MB/s eta 0:00:00 MB/s eta 0:00:01
# Downloading filelock-3.12.4-py3-none-any.whl (11 kB)
# Downloading flatbuffers-23.5.26-py2.py3-none-any.whl (26 kB)
# Downloading frozenlist-1.4.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (250 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.5/250.5 kB 6.7 MB/s eta 0:00:000:00:01
# Downloading fsspec-2023.9.1-py3-none-any.whl (173 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.4/173.4 kB 27.5 MB/s eta 0:00:00
# Downloading gpt4all-2.0.2-py3-none-manylinux1_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 6.8 MB/s eta 0:00:00m eta 0:00:010:01:01
# Downloading httptools-0.6.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (405 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 405.9/405.9 kB 10.6 MB/s eta 0:00:00MB/s eta 0:00:01
# Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 6.6 MB/s eta 0:00:00m eta 0:00:01
# Downloading importlib_resources-6.0.1-py3-none-any.whl (34 kB)
# Downloading joblib-1.3.2-py3-none-any.whl (302 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.2/302.2 kB 7.4 MB/s eta 0:00:0042.2 MB/s eta 0:00:01
# Downloading langchain-0.0.295-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 6.7 MB/s eta 0:00:00m eta 0:00:010:010:01
# Downloading langsmith-0.0.38-py3-none-any.whl (38 kB)
# Downloading marshmallow-3.20.1-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 10.7 MB/s eta 0:00:00
# Downloading numexpr-2.8.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (386 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.0/386.0 kB 10.4 MB/s eta 0:00:000:00:01
# Downloading numpy-1.26.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 4.8 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading onnxruntime-1.15.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 4.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading pandas-2.1.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 5.2 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading posthog-3.0.2-py2.py3-none-any.whl (37 kB)
# Downloading protobuf-4.24.3-cp37-abi3-manylinux2014_x86_64.whl (311 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.6/311.6 kB 7.4 MB/s eta 0:00:000:00:01
# Downloading pulsar_client-3.3.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 4.8 MB/s eta 0:00:00m eta 0:00:010:01:01
# Downloading pydantic-1.10.12-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 4.2 MB/s eta 0:00:00m eta 0:00:010:01:01
# Downloading regex-2023.8.8-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (782 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 782.4/782.4 kB 5.0 MB/s eta 0:00:005.6 MB/s eta 0:00:01m
# Downloading safetensors-0.3.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 4.3 MB/s eta 0:00:000:00:010:00:01:01
# Downloading scikit_learn-1.3.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 4.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading scipy-1.11.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (36.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.3/36.3 MB 4.4 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading SQLAlchemy-2.0.21-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 4.0 MB/s eta 0:00:000:00:010:00:01:01
# Downloading starlette-0.27.0-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 11.1 MB/s eta 0:00:00
# Downloading tenacity-8.2.3-py3-none-any.whl (24 kB)
# Downloading threadpoolctl-3.2.0-py3-none-any.whl (15 kB)
# Using cached tqdm-4.66.1-py3-none-any.whl (78 kB)
# Downloading transformers-4.33.2-py3-none-any.whl (7.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 4.5 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading typing_extensions-4.8.0-py3-none-any.whl (31 kB)
# Downloading urllib3-2.0.4-py3-none-any.whl (123 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.9/123.9 kB 18.4 MB/s eta 0:00:00
# Downloading uvicorn-0.23.2-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 11.6 MB/s eta 0:00:00
# Downloading watchfiles-0.20.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 4.6 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Downloading xformers-0.0.21-cp311-cp311-manylinux2014_x86_64.whl (167.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.0/167.0 MB 2.6 MB/s eta 0:00:00m eta 0:00:010:00:02
# Downloading uvloop-0.19.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 4.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# Building wheels for collected packages: bs4, googlemaps, llama_cpp_python
#   Building wheel for bs4 (setup.py) ... done
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1256 sha256=9e20b752ba8bdd095ff0610932aeddc103ce9f2813dcaa5f7dc9d958bc1bbc11
#   Stored in directory: /home/koffi369/.cache/pip/wheels/d4/c8/5b/b5be9c20e5e4503d04a6eac8a3cd5c2393505c29f02bea0960
#   Building wheel for googlemaps (setup.py) ... done
#   Created wheel for googlemaps: filename=googlemaps-4.10.0-py3-none-any.whl size=40713 sha256=782bc21a5c264d2930123fddf6c5c58e09cc15bce9b6503111aeef198847ff06
#   Stored in directory: /home/koffi369/.cache/pip/wheels/f1/09/77/3cc2f5659cbc62341b30f806aca2b25e6a26c351daa5b1f49a
#   Building wheel for llama_cpp_python (pyproject.toml) ... done
#   Created wheel for llama_cpp_python: filename=llama_cpp_python-0.2.11-cp311-cp311-manylinux_2_35_x86_64.whl size=1023483 sha256=94073718b600368895f22af0dd27770a2cd1a5b7427ed953a750fcac26036c82
#   Stored in directory: /home/koffi369/.cache/pip/wheels/f2/35/aa/ae233f34d3f2db880f078f01c4ab535f1674bebab171b5c808
# Successfully built bs4 googlemaps llama_cpp_python
# Installing collected packages: tokenizers, sentencepiece, safetensors, pyreadline3, PyPika, monotonic, flatbuffers, websockets, uvloop, urllib3, tzdata, typing_extensions, tqdm, threadpoolctl, termcolor, tenacity, sniffio, regex, python-dotenv, protobuf, numpy, networkx, mypy-extensions, multidict, marshmallow, joblib, importlib-resources, humanfriendly, httptools, h11, greenlet, fsspec, frozenlist, filelock, exceptiongroup, diskcache, colorama, click, charset-normalizer, certifi, bcrypt, backoff, async-timeout, yarl, uvicorn, typing-inspect, SQLAlchemy, scipy, pydantic, pulsar-client, pandas, numexpr, nltk, llama_cpp_python, google, coloredlogs, chroma-hnswlib, bs4, anyio, aiosignal, watchfiles, starlette, scikit-learn, posthog, onnxruntime, langsmith, huggingface-hub, gpt4all, googlemaps, dataclasses-json, aiohttp, transformers, langchain, fastapi, chromadb, xformers
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.18
#     Uninstalling urllib3-1.26.18:
#       Successfully uninstalled urllib3-1.26.18
#   Attempting uninstall: typing_extensions
#     Found existing installation: typing_extensions 4.9.0
#     Uninstalling typing_extensions-4.9.0:
#       Successfully uninstalled typing_extensions-4.9.0
#   Attempting uninstall: sniffio
#     Found existing installation: sniffio 1.2.0
#     Uninstalling sniffio-1.2.0:
#       Successfully uninstalled sniffio-1.2.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.1
#     Uninstalling numpy-1.24.1:
#       Successfully uninstalled numpy-1.24.1
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.0
#     Uninstalling networkx-3.0:
#       Successfully uninstalled networkx-3.0
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.9.0
#     Uninstalling filelock-3.9.0:
#       Successfully uninstalled filelock-3.9.0
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 2.0.4
#     Uninstalling charset-normalizer-2.0.4:
#       Successfully uninstalled charset-normalizer-2.0.4
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2023.11.17
#     Uninstalling certifi-2023.11.17:
#       Successfully uninstalled certifi-2023.11.17
#   Attempting uninstall: anyio
#     Found existing installation: anyio 3.5.0
#     Uninstalling anyio-3.5.0:
#       Successfully uninstalled anyio-3.5.0
# Successfully installed PyPika-0.48.9 SQLAlchemy-2.0.21 aiohttp-3.8.5 aiosignal-1.3.1 anyio-4.0.0 async-timeout-4.0.3 backoff-2.2.1 bcrypt-4.0.1 bs4-0.0.1 certifi-2023.7.22 charset-normalizer-3.2.0 chroma-hnswlib-0.7.3 chromadb-0.4.10 click-8.1.7 colorama-0.4.6 coloredlogs-15.0.1 dataclasses-json-0.5.14 diskcache-5.6.3 exceptiongroup-1.1.3 fastapi-0.99.1 filelock-3.12.4 flatbuffers-23.5.26 frozenlist-1.4.0 fsspec-2023.9.1 google-3.0.0 googlemaps-4.10.0 gpt4all-2.0.2 greenlet-2.0.2 h11-0.14.0 httptools-0.6.0 huggingface-hub-0.16.4 humanfriendly-10.0 importlib-resources-6.0.1 joblib-1.3.2 langchain-0.0.295 langsmith-0.0.38 llama_cpp_python-0.2.11 marshmallow-3.20.1 monotonic-1.6 multidict-6.0.4 mypy-extensions-1.0.0 networkx-3.1 nltk-3.8.1 numexpr-2.8.6 numpy-1.26.0 onnxruntime-1.15.1 pandas-2.1.1 posthog-3.0.2 protobuf-4.24.3 pulsar-client-3.3.0 pydantic-1.10.12 pyreadline3-3.4.1 python-dotenv-1.0.0 regex-2023.8.8 safetensors-0.3.3 scikit-learn-1.3.1 scipy-1.11.2 sentencepiece-0.1.99 sniffio-1.3.0 starlette-0.27.0 tenacity-8.2.3 termcolor-2.3.0 threadpoolctl-3.2.0 tokenizers-0.13.3 tqdm-4.66.1 transformers-4.33.2 typing-inspect-0.9.0 typing_extensions-4.8.0 tzdata-2023.3 urllib3-2.0.4 uvicorn-0.23.2 uvloop-0.19.0 watchfiles-0.20.0 websockets-11.0.3 xformers-0.0.21 yarl-1.9.2

# %%
# !python -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /home/koffi369/anaconda3/envs/memory_agent/lib/python3.11/site-packages (23.3.1)
# Collecting pip
#   Downloading pip-23.3.2-py3-none-any.whl.metadata (3.5 kB)
# Downloading pip-23.3.2-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 931.4 kB/s eta 0:00:000:00:01m eta 0:00:01
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 23.3.1
#     Uninstalling pip-23.3.1:
#       Successfully uninstalled pip-23.3.1
# Successfully installed pip-23.3.2

# %%
# !pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu117
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu117
# Collecting torch
#   Downloading https://download.pytorch.org/whl/cu117/torch-2.0.1%2Bcu117-cp311-cp311-linux_x86_64.whl (1843.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 GB 3.9 MB/s eta 0:00:000m eta 0:00:010:00:01
# Collecting torchvision
#   Downloading https://download.pytorch.org/whl/cu117/torchvision-0.15.2%2Bcu117-cp311-cp311-linux_x86_64.whl (6.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 50.1 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Collecting torchaudio
#   Downloading https://download.pytorch.org/whl/cu117/torchaudio-2.0.2%2Bcu117-cp311-cp311-linux_x86_64.whl (4.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 45.1 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Collecting filelock (from torch)
#   Downloading https://download.pytorch.org/whl/filelock-3.9.0-py3-none-any.whl (9.7 kB)
# Requirement already satisfied: typing-extensions in /home/koffi369/anaconda3/envs/memory_agent/lib/python3.11/site-packages (from torch) (4.9.0)
# Collecting sympy (from torch)
#   Downloading https://download.pytorch.org/whl/sympy-1.12-py3-none-any.whl (5.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 30.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting networkx (from torch)
#   Downloading https://download.pytorch.org/whl/networkx-3.0-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 16.9 MB/s eta 0:00:00m eta 0:00:010:01
# Requirement already satisfied: jinja2 in /home/koffi369/anaconda3/envs/memory_agent/lib/python3.11/site-packages (from torch) (3.1.2)
# Collecting triton==2.0.0 (from torch)
#   Downloading https://download.pytorch.org/whl/triton-2.0.0-1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (63.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 MB 34.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting cmake (from triton==2.0.0->torch)
#   Downloading https://download.pytorch.org/whl/cmake-3.25.0-py2.py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 41.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting lit (from triton==2.0.0->torch)
#   Downloading https://download.pytorch.org/whl/lit-15.0.7.tar.gz (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.3/132.3 kB 9.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting numpy (from torchvision)
#   Downloading https://download.pytorch.org/whl/numpy-1.24.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 49.6 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: requests in /home/koffi369/anaconda3/envs/memory_agent/lib/python3.11/site-packages (from torchvision) (2.31.0)
# Collecting pillow!=8.3.*,>=5.3.0 (from torchvision)
#   Downloading https://download.pytorch.org/whl/Pillow-9.3.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 54.7 MB/s eta 0:00:0031m67.1 MB/s eta 0:00:01
# Requirement already satisfied: MarkupSafe>=2.0 in /home/koffi369/anaconda3/envs/memory_agent/lib/python3.11/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/koffi369/anaconda3/envs/memory_agent/lib/python3.11/site-packages (from requests->torchvision) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/koffi369/anaconda3/envs/memory_agent/lib/python3.11/site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/koffi369/anaconda3/envs/memory_agent/lib/python3.11/site-packages (from requests->torchvision) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /home/koffi369/anaconda3/envs/memory_agent/lib/python3.11/site-packages (from requests->torchvision) (2023.11.17)
# Collecting mpmath>=0.19 (from sympy->torch)
#   Downloading https://download.pytorch.org/whl/mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 23.5 MB/s eta 0:00:00
# Building wheels for collected packages: lit
#   Building wheel for lit (setup.py) ... done
#   Created wheel for lit: filename=lit-15.0.7-py3-none-any.whl size=89989 sha256=ff009b80005e4fecf82b305342d9ed8b04821e9eec2a4fcec50486ae47cf733e
#   Stored in directory: /home/koffi369/.cache/pip/wheels/fc/5d/45/34fe9945d5e45e261134e72284395be36c2d4828af38e2b0fe
# Successfully built lit
# Installing collected packages: mpmath, lit, cmake, sympy, pillow, numpy, networkx, filelock, triton, torch, torchvision, torchaudio
# Successfully installed cmake-3.25.0 filelock-3.9.0 lit-15.0.7 mpmath-1.3.0 networkx-3.0 numpy-1.24.1 pillow-9.3.0 sympy-1.12 torch-2.0.1+cu117 torchaudio-2.0.2+cu117 torchvision-0.15.2+cu117 triton-2.0.0

# %%
# $ sqlite3 chroma.sqlite3
# sqlite> .tables
# table1  table2  table3
# sqlite> SELECT * FROM table1;

# %%
# !sqlite3 chroma.sqlite3
# Out:
# SQLite version 3.41.2 2023-03-22 11:56:21
# Enter ".help" for usage hints.
# sqlite> ^C
# sqlite>

# %% [markdown]
# ## Clean version

# %%
################################################################### Utils
import numpy as np
from functools import wraps
from termcolor import colored


def cosine_similarity(a: np.ndarray, b: np.ndarray):
    return np.dot(a, b.T) / (np.linalg.norm(a) * np.linalg.norm(b))




def logging(enabled = True, message = "", color = "yellow"):
    def decorator(func):
        @wraps(func)
        def wrapper(*args, **kwargs):
            if enabled:
                print(f"LOG: {colored(message, color = color)}")
            return func(*args, **kwargs)
        return wrapper
    return decorator



################################################################ Embeddings
# from sklearn.decomposition import PCA

import torch
import os
import numpy as np
from transformers import AutoModel, AutoTokenizer
from chromadb import EmbeddingFunction
# from gpt4all import Embed4All
# from dotenv import dotenv_values

# env = dotenv_values(".env")
# os.environ['HUGGINGFACE_HUB_CACHE'] = env['HUGGINGFACE_HUB_CACHE']



class BaseEmbedder(EmbeddingFunction):
    def __init__(self):
        pass

    def get_embeddings(self, texts):
        raise NotImplementedError("Subclasses should implement this!")

    def __call__(self, text):
        return self.get_embeddings(text)


class GPT4AllEmbedder(BaseEmbedder):
    def __init__(self):
        self.embedder = Embed4All() # default: all-MiniLM-L6-v2

    def get_embeddings(self, texts):
        if type(texts) == str:
            texts = [texts]
        
        embeddings = []
        for text in texts:
            embeddings.append(self.embedder.embed(text))

        return embeddings

    def __call__(self, text):
        return self.get_embeddings(text)


class HFEmbedder(BaseEmbedder):
    def __init__(self, model = 'princeton-nlp/sup-simcse-roberta-large'): #sentence-transformers/all-MiniLM-L6-v2
        self.device = 'cuda' if torch.cuda.is_available() else 'cpu'
        self.model = AutoModel.from_pretrained(model).to(self.device)
        self.tokenizer = AutoTokenizer.from_pretrained(model)
        

    def get_embeddings(self, texts):
        if type(texts) == str:
            texts = [texts]

        inputs = self.tokenizer(texts, padding=True, truncation=True, return_tensors="pt").to(self.device)

        with torch.no_grad():
            embeddings = self.model(**inputs, output_hidden_states=True, return_dict=True).pooler_output.detach().cpu().numpy()

        norms = np.linalg.norm(embeddings, axis=1, keepdims=True)
        normalized_embeddings = embeddings / norms

        return normalized_embeddings.tolist()

    def __call__(self, text):
        return self.get_embeddings(text)

    
# class HFEmbedder(BaseEmbedder):
#     def __init__(self, model = 'princeton-nlp/sup-simcse-roberta-large'): #sentence-transformers/all-MiniLM-L6-v2
#         self.device = 'cuda' if torch.cuda.is_available() else 'cpu'
#         self.model = AutoModel.from_pretrained(model).to(self.device)
#         self.tokenizer = AutoTokenizer.from_pretrained(model)
        

#     def get_embeddings(self, texts):
#         if type(texts) == str:
#             texts = [texts]

#         inputs = self.tokenizer(texts, padding=True, truncation=True, return_tensors="pt").to(self.device)

#         with torch.no_grad():
#             embeddings = self.model(**inputs, output_hidden_states=True, return_dict=True).pooler_output.detach().cpu().numpy()

#         pca = PCA(n_components=384)
#         reduced_embeddings = pca.fit_transform(embeddings)    
#         norms = np.linalg.norm(embeddings, axis=1, keepdims=True)
#         normalized_embeddings = embeddings / norms

#         return normalized_embeddings.tolist()

#     def __call__(self, text):
#         return self.get_embeddings(text)



################################################################### VectDB
import chromadb
import uuid
import datetime
# from embedder import BaseEmbedder, HFEmbedder
# from dotenv import dotenv_values

# env = dotenv_values(".env")
# DB_PATH = env["DB_PATH"]
DB_PATH = './'

class CollectionOperator():
    def __init__(self, collection_name, db_path = DB_PATH, embedder: BaseEmbedder = None):
        self.embedder = embedder
        self.client = chromadb.PersistentClient(path = db_path)
        self.collection = self.client.get_or_create_collection(name = collection_name, embedding_function = self.embedder.get_embeddings)

    def add(self, text, metadata = {}):
        metadata['timestamp'] = str(datetime.datetime.now())

        self.collection.add(
            documents = [text],
            metadatas = [metadata],
            ids = [str(uuid.uuid4())]
        )

    def delete(self, id):
        self.collection.delete(id)

    def query(self, query, n_results, return_text = True):
        query = self.collection.query(
            query_texts = query,
            n_results = n_results,
        )

        if return_text:
            return query['documents'][0]
        else:
            return query




######################################################################### new llm

from typing import List, Optional, Any
from gpt4all import GPT4All
from llama_cpp import Llama

class BaseLLM():
    def __init__(self, model_name: Optional[str] = None, model_path: Optional[str] = None) -> None:
        # self.user = '''We have a database that represents the memory of a robot. Using this memory the robot is 
        # supposed to provide relevent and extremely accurate informations in order to solve a task or answer a question. 
        # Your goal is to analyse the informations in the memory and and help the robot to provide the most relevent informations to solve the task ''' #"USER"
        
        # self.user = '''We have a database that serves as the memory of a robot. This memory is used by the robot to provide relevant and highly accurate 
        # information to solve tasks or answer questions. Your goal is to analyze the information in the memory and assist the robot in providing the most 
        # relevant information to solve the task.'''

        self.user = """
I will provide you with a Document retrieved from a database. Your goal is to answer a question or solve a task by only using the informations from this  Document.
"""

        # self.user = """
        #     I will provide you with MEMORY CHUNKs retrieved from a database. Your goal is to use these MEMORY CHUNKs to solve a task or answer a question. 
        #     Rely solely on the information from the MEMORY CHUNKs for solving the task or responding to the query.
        #     """

                
        # self.assistant = '''
        # Here is the set of rules you should explicetly follow  : 
        # Rules: 
        # 1 - If there is no relevent information in the memory to answer the question you must answer by "no relevent information "
        # 2 - You are not allowed any type of information outside of the provided memory to answer the question
        # Your Response:''' #"ASSISTANT"
        
        # self.assistant = """
        #     Please adhere to these essential rules when formulating your responses:
            
        #     Rule 1: If the MEMORY CHUNKs do not contain relevant information to solve the task or answer the question, respond explicitly with "None".
        #     Rule 2: Do not use any information beyond what is provided in the MEMORY CHUNKs.
        #     Rule 3: In cases where the MEMORY CHUNKs' information is irrelevant to the task, respond explicitly with "None".
        #     Rule 4: Provide a direct answer to the question without any additional commentary.
        #     """

        self.assistant = """
Here are some important rules to follow:

Rule 1: If the Document  do not contain any elevant information to solve the task or answer the question, respond explicitly with "None".
Rule 2: Do not use any information except what is provided in the Document.
Rule 4: Provide a direct answer to the question without any additional comment.
"""
        self.input = "Here is the Document:"
        # self.input = "Utilize the following MEMORY CHUNKs explicitly:"
        self.streaming = False

        ##############
        self.memory_context = lambda question: f""" 
        Here is the task  
        Task: {question} 
        """
        ##############

        # self.search_context = lambda question: f"""
        # You have been given access to the Internet. By considering below search results, summarize the information if its provided in search result, else just answer without search results: {question}
        # """

    def generate(self, request: str, streaming: bool) -> Any:
        raise NotImplementedError

    def response(self, request: str) -> Any:
        print(request)
        return self.generate(f"{self.user}:\n{request}\n{self.assistant}:\n", streaming = self.streaming)

    ############################################################################################################################
    def memory_response(self, request: str, memory_queries: List[str]) -> Any:
        queries = f"{self.user}\n{self.memory_context(request)}\n{self.input}\n{self.assistant}:\n"


        for i, query in enumerate(memory_queries):
            queries += f"MEMORY CHUNK {i}: {query}\n"

        # queries = queries.replace('\n', '')

        return self.generate(queries, streaming = self.streaming)
    ############################################################################################################################

    # def search_response(self, request: str, search_results: List[dict[str, str, str]]) -> Any:
    #     queries = f"{self.user}:\n{self.search_context(request)}\n{self.input}:\n"

    #     for i, query in enumerate(search_results):
    #         queries += f"SEARCH TITLE: {query['title']}\nSEARCH LINK: {query['link']}\nSEARCH CONTENT: {query['content']}\n"

    #     queries += f"{self.assistant}:\n"

    #     return self.generate(queries, streaming = self.streaming)

class GPT4AllLLM(BaseLLM):
    def __init__(self, model_name: Optional[str] = None, model_path: Optional[str] = None) -> None:
        super().__init__(model_name, model_path)
        
        self.gpt = GPT4All(model_name = model_name, model_path = model_path, verbose=False)

    def generate(self, request: str, streaming: bool) -> Any:
        return self.gpt.generate(prompt = request, streaming = streaming)

class LlamaCPPLLM(BaseLLM):
    def __init__(self, model_name: Optional[str] = None) -> None:
        super().__init__(model_name)
        
        self.gpt = Llama(model_path = model_name, n_ctx=2048, verbose=False)

    def generate(self, request: str, streaming: bool) -> Any:
        return self.gpt.create_completion(prompt = request, stream = streaming, stop=[f"{self.user}:"])



######################################################################### summarizer


import os
import torch
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
from transformers import pipeline
from dotenv import dotenv_values

# env = dotenv_values(".env")
# os.environ['HUGGINGFACE_HUB_CACHE'] = env['HUGGINGFACE_HUB_CACHE']

# checkpoint = "t5-small"
# checkpoint = "google/mt5-small"
# checkpoint = "facebook/bart-large-cnn"
checkpoint = "sshleifer/distilbart-cnn-12-6"

# class Summarizer():
#     def __init__(self, model = checkpoint) -> None:
#         self.summarizer = pipeline("summarization", model = model)#, min_length = 30, max_length = 300

#     def summarize(self, text: str, min_length_ratio = 0.3, max_length_ratio = 1.):
#         if len(text) < 5:
#             return text

#         prompt = f"summarize: {text}"

#         return self.summarizer(prompt,  min_length = int(min_length_ratio * len(prompt.split(" "))), max_length = int(max_length_ratio * len(prompt.split(" "))))[0]['summary_text']

#     def __call__(self, text, min_length_ratio = 0.3, max_length_ratio = 1.):
#         return self.summarize(text, min_length_ratio, max_length_ratio)



# https://discuss.huggingface.co/t/summarization-on-long-documents/920/23
# https://www.width.ai/post/4-long-text-summarization-methods

class Summarizer():
    def __init__(self, model = checkpoint) -> None:
        self.device = 'cuda' if torch.cuda.is_available() else 'cpu'
        self.model = AutoModelForSeq2SeqLM.from_pretrained(model).to(self.device)
        self.tokenizer = AutoTokenizer.from_pretrained(model)

        # self.model = BartForConditionalGeneration.from_pretrained(model_name)#.to('cuda')
        # self.tokenizer = BartTokenizer.from_pretrained(model_name)

    def summarize(self, text: str, min_length = 30, max_length = 100):
        """Fixed-size chunking"""
        inputs_no_trunc = self.tokenizer(text, max_length=None, return_tensors='pt', truncation=False)
        if len(inputs_no_trunc['input_ids'][0]) < 30:
            return text

        # min_length = min_length_ratio * len(inputs)
        # max_length = max_length_ratio * len(inputs)
        
        inputs_batch_lst = []
        chunk_start = 0
        chunk_end = self.tokenizer.model_max_length  # == 1024 for Bart
        while chunk_start <= len(inputs_no_trunc['input_ids'][0]):
            inputs_batch = inputs_no_trunc['input_ids'][0][chunk_start:chunk_end]  # get batch of n tokens
            inputs_batch = torch.unsqueeze(inputs_batch, 0)
            inputs_batch_lst.append(inputs_batch)
            chunk_start += self.tokenizer.model_max_length  # == 1024 for Bart
            chunk_end += self.tokenizer.model_max_length  # == 1024 for Bart
        summary_ids_lst = [self.model.generate(inputs.to(self.device), num_beams=4, min_length=min_length, max_length=max_length, early_stopping=True) for inputs in inputs_batch_lst]

        summary_batch_lst = []
        for summary_id in summary_ids_lst:
            summary_batch = [self.tokenizer.decode(g, skip_special_tokens=True, clean_up_tokenization_spaces=False) for g in summary_id]
            summary_batch_lst.append(summary_batch[0])
        summary_all = '\n'.join(summary_batch_lst)

        return summary_all

    def __call__(self, text, min_length = 30, max_length = 100):
        return self.summarize(text, min_length, max_length)

######################################################################### llm Agent



# from llm import BaseLLM
# # from search_engine import SearchEngine
# from summarizer import Summarizer
# from query_db import CollectionOperator


# from utils import logging




enable_logging = True

class LLMAgent():
    def __init__(
        self, 
        llm: BaseLLM = None, 
        tm_qdb: CollectionOperator = None, 
        summarizer: Summarizer = None, 
        # search_engine: SearchEngine = None,
        use_summarizer = True,
       
    ) -> None:

        self.llm = llm
        self.tm_qdb = tm_qdb
        self.memory_access_threshold = 1.5
        # self.similarity_threshold = 0.5 # [0; 1]
        self.db_n_results = 3
        self.se_n_results = 3
        self.use_summarizer = use_summarizer
       
        self.summarizer = summarizer
        # self.search_engine = search_engine
       

    @logging(enable_logging, message = "[Adding to memory]")
    def add(self, request):
        # summary = self.summarizer(f"{self.llm.user}:\n{request}\n{self.llm.assistant}:\n{''.join(response)}")
        
        summary = self.summarize(request) if self.use_summarizer else request

        self.tm_qdb.add(summary) if summary != "" else None

        response = self.llm.response(request)

        return response
        
    ###################################### New Info to Memory without chat
    
    def add_info_to_mem(self, request):
        # summary = self.summarizer(f"{self.llm.user}:\n{request}\n{self.llm.assistant}:\n{''.join(response)}")
        
        summary = self.summarize(request) if self.use_summarizer else request

        self.tm_qdb.add(summary) if summary != "" else None
        print(f" '{summary}' was added to the memory")

        # response = self.llm.response(request)

    
     ###################################### Get response without chat #####

    
    def memory_response_retriver(self, request):
        memory_queries_data = self.tm_qdb.query(request, n_results = self.db_n_results, return_text = False)
        memory_queries = memory_queries_data['documents'][0]
        memory_queries_distances = memory_queries_data['distances'][0]
    
        acceptable_memory_queries = []
    
        for query, distance in list(zip(memory_queries, memory_queries_distances)):
            # print(f"Query: {query}, Distance: {distance}")
            if distance < self.memory_access_threshold:
            # if (1 - distance) >= self.similarity_threshold:
                acceptable_memory_queries.append(query)
    
        if len(acceptable_memory_queries) > 0:
            response = self.llm.memory_response(request, acceptable_memory_queries)
        else:
            # response = self.llm.response(request) #TODO: add another solution
            response  = "None"    
        return response
        

    ############################################################################################################################
    @logging(enable_logging, message = "[Querying memory]")
    def memory_response(self, request):
        memory_queries_data = self.tm_qdb.query(request, n_results = self.db_n_results, return_text = False)
        memory_queries = memory_queries_data['documents'][0]
        memory_queries_distances = memory_queries_data['distances'][0]

        acceptable_memory_queries = []

        for query, distance in list(zip(memory_queries, memory_queries_distances)):
            # print(f"Query: {query}, Distance: {distance}")
            if distance < self.memory_access_threshold:
            # if (1 - distance) >= self.similarity_threshold:
                acceptable_memory_queries.append(query)

        if len(acceptable_memory_queries) > 0:
            response = self.llm.memory_response(request, acceptable_memory_queries)
        else:
            response = self.llm.response(request) #TODO: add another solution

        return response
    ############################################################################################################################
    # @logging(enable_logging, message = "[Searching]")
    # def search(self, request):
    #     search_response = self.search_engine.search(request, n_results = self.se_n_results)

    #     for response in search_response:
    #         response['content'] = self.summarize(response['content'])

    #     return self.llm.search_response(request, search_response)

    # @logging(enable_logging, message = "[Summarizing]", color = "green")
    def summarize(self, text, min_length = 30, max_length = 100):
        return self.summarizer(text, min_length, max_length)


    @logging(enable_logging, message = "[Response]")
    def response(self, request):
        return self.llm.response(request)

    
    def generate(self, request: str):
        response = self.memory_response_retriver(request)
        # if request.upper().startswith("MEM"):
        #     response = self.memory_response(request[len("MEM"):])
        # elif request.upper().startswith("REMEM"): #and len(acceptable_memory_queries) == 0
        #     response = self.add(request[len("REMEM"):])
        # # elif request.upper().startswith("WEB"):
        # #     response = self.search(request[len("WEB"):])
        # else:
        #     response = self.response(request)    
        return response

# %%
import os
# Set the model path
os.environ['LLM_PATH'] = 'nous-hermes-llama2-13b.Q4_0.gguf'

port_lib_name = "LLAMA_CPP"


if port_lib_name == "LLAMA_CPP":
    LLM = LlamaCPPLLM

else:
    LLM = GPT4AllLLM


llm = LLM(os.environ.get('LLM_PATH'))

embedder = HFEmbedder()

summarizer = Summarizer()

total_memory_co = CollectionOperator("total-memory", embedder = embedder)

llm_agent = LLMAgent(llm, total_memory_co, summarizer, use_summarizer = True)
# Out:
# llama_model_loader: loaded meta data with 19 key-value pairs and 363 tensors from nous-hermes-llama2-13b.Q4_0.gguf (version GGUF V2 (latest))
# llama_model_loader: - tensor    0:                token_embd.weight q4_0     [  5120, 32032,     1,     1 ]
# llama_model_loader: - tensor    1:              blk.0.attn_q.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor    2:              blk.0.attn_k.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor    3:              blk.0.attn_v.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor    4:         blk.0.attn_output.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor    5:            blk.0.ffn_gate.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor    6:              blk.0.ffn_up.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor    7:            blk.0.ffn_down.weight q4_0     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor    8:           blk.0.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor    9:            blk.0.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   10:              blk.1.attn_q.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   11:              blk.1.attn_k.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   12:              blk.1.attn_v.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   13:         blk.1.attn_output.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   14:            blk.1.ffn_gate.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   15:              blk.1.ffn_up.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   16:            blk.1.ffn_down.weight q4_0     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor   17:           blk.1.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   18:            blk.1.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   19:              blk.2.attn_q.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   20:              blk.2.attn_k.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   21:              blk.2.attn_v.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   22:         blk.2.attn_output.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   23:            blk.2.ffn_gate.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   24:              blk.2.ffn_up.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   25:            blk.2.ffn_down.weight q4_0     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor   26:           blk.2.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   27:            blk.2.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   28:              blk.3.attn_q.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   29:              blk.3.attn_k.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   30:              blk.3.attn_v.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   31:         blk.3.attn_output.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   32:            blk.3.ffn_gate.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   33:              blk.3.ffn_up.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   34:            blk.3.ffn_down.weight q4_0     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor   35:           blk.3.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   36:            blk.3.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   37:              blk.4.attn_q.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   38:              blk.4.attn_k.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   39:              blk.4.attn_v.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   40:         blk.4.attn_output.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   41:            blk.4.ffn_gate.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   42:              blk.4.ffn_up.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   43:            blk.4.ffn_down.weight q4_0     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor   44:           blk.4.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   45:            blk.4.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   46:              blk.5.attn_q.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   47:              blk.5.attn_k.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   48:              blk.5.attn_v.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   49:         blk.5.attn_output.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   50:            blk.5.ffn_gate.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   51:              blk.5.ffn_up.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   52:            blk.5.ffn_down.weight q4_0     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor   53:           blk.5.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   54:            blk.5.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   55:              blk.6.attn_q.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   56:              blk.6.attn_k.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   57:              blk.6.attn_v.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   58:         blk.6.attn_output.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   59:            blk.6.ffn_gate.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   60:              blk.6.ffn_up.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   61:            blk.6.ffn_down.weight q4_0     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor   62:           blk.6.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   63:            blk.6.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   64:              blk.7.attn_q.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   65:              blk.7.attn_k.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   66:              blk.7.attn_v.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   67:         blk.7.attn_output.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   68:            blk.7.ffn_gate.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   69:              blk.7.ffn_up.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   70:            blk.7.ffn_down.weight q4_0     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor   71:           blk.7.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   72:            blk.7.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   73:              blk.8.attn_q.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   74:              blk.8.attn_k.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   75:              blk.8.attn_v.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   76:         blk.8.attn_output.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   77:            blk.8.ffn_gate.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   78:              blk.8.ffn_up.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   79:            blk.8.ffn_down.weight q4_0     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor   80:           blk.8.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   81:            blk.8.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   82:              blk.9.attn_q.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   83:              blk.9.attn_k.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   84:              blk.9.attn_v.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   85:         blk.9.attn_output.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   86:            blk.9.ffn_gate.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   87:              blk.9.ffn_up.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   88:            blk.9.ffn_down.weight q4_0     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor   89:           blk.9.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   90:            blk.9.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   91:             blk.10.attn_q.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   92:             blk.10.attn_k.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   93:             blk.10.attn_v.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   94:        blk.10.attn_output.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor   95:           blk.10.ffn_gate.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   96:             blk.10.ffn_up.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor   97:           blk.10.ffn_down.weight q4_0     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor   98:          blk.10.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor   99:           blk.10.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  100:             blk.11.attn_q.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  101:             blk.11.attn_k.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  102:             blk.11.attn_v.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  103:        blk.11.attn_output.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  104:           blk.11.ffn_gate.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  105:             blk.11.ffn_up.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  106:           blk.11.ffn_down.weight q4_0     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  107:          blk.11.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  108:           blk.11.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  109:             blk.12.attn_q.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  110:             blk.12.attn_k.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  111:             blk.12.attn_v.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  112:        blk.12.attn_output.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  113:           blk.12.ffn_gate.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  114:             blk.12.ffn_up.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  115:           blk.12.ffn_down.weight q4_0     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  116:          blk.12.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  117:           blk.12.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  118:             blk.13.attn_q.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  119:             blk.13.attn_k.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  120:             blk.13.attn_v.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  121:        blk.13.attn_output.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  122:           blk.13.ffn_gate.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  123:             blk.13.ffn_up.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  124:           blk.13.ffn_down.weight q4_0     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  125:          blk.13.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  126:           blk.13.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  127:             blk.14.attn_q.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  128:             blk.14.attn_k.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  129:             blk.14.attn_v.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  130:        blk.14.attn_output.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  131:           blk.14.ffn_gate.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  132:             blk.14.ffn_up.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  133:           blk.14.ffn_down.weight q4_0     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  134:          blk.14.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  135:           blk.14.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  136:             blk.15.attn_q.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  137:             blk.15.attn_k.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  138:             blk.15.attn_v.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  139:        blk.15.attn_output.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  140:           blk.15.ffn_gate.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  141:             blk.15.ffn_up.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  142:           blk.15.ffn_down.weight q4_0     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  143:          blk.15.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  144:           blk.15.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  145:             blk.16.attn_q.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  146:             blk.16.attn_k.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  147:             blk.16.attn_v.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  148:        blk.16.attn_output.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  149:           blk.16.ffn_gate.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  150:             blk.16.ffn_up.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  151:           blk.16.ffn_down.weight q4_0     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  152:          blk.16.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  153:           blk.16.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  154:             blk.17.attn_q.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  155:             blk.17.attn_k.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  156:             blk.17.attn_v.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  157:        blk.17.attn_output.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  158:           blk.17.ffn_gate.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  159:             blk.17.ffn_up.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  160:           blk.17.ffn_down.weight q4_0     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  161:          blk.17.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  162:           blk.17.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  163:             blk.18.attn_q.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  164:             blk.18.attn_k.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  165:             blk.18.attn_v.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  166:        blk.18.attn_output.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  167:           blk.18.ffn_gate.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  168:             blk.18.ffn_up.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  169:           blk.18.ffn_down.weight q4_0     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  170:          blk.18.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  171:           blk.18.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  172:             blk.19.attn_q.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  173:             blk.19.attn_k.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  174:             blk.19.attn_v.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  175:        blk.19.attn_output.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  176:           blk.19.ffn_gate.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  177:             blk.19.ffn_up.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  178:           blk.19.ffn_down.weight q4_0     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  179:          blk.19.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  180:           blk.19.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  181:             blk.20.attn_q.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  182:             blk.20.attn_k.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  183:             blk.20.attn_v.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  184:        blk.20.attn_output.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  185:           blk.20.ffn_gate.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  186:             blk.20.ffn_up.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  187:           blk.20.ffn_down.weight q4_0     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  188:          blk.20.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  189:           blk.20.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  190:             blk.21.attn_q.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  191:             blk.21.attn_k.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  192:             blk.21.attn_v.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  193:        blk.21.attn_output.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  194:           blk.21.ffn_gate.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  195:             blk.21.ffn_up.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  196:           blk.21.ffn_down.weight q4_0     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  197:          blk.21.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  198:           blk.21.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  199:             blk.22.attn_q.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  200:             blk.22.attn_k.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  201:             blk.22.attn_v.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  202:        blk.22.attn_output.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  203:           blk.22.ffn_gate.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  204:             blk.22.ffn_up.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  205:           blk.22.ffn_down.weight q4_0     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  206:          blk.22.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  207:           blk.22.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  208:             blk.23.attn_q.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  209:             blk.23.attn_k.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  210:             blk.23.attn_v.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  211:        blk.23.attn_output.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  212:           blk.23.ffn_gate.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  213:             blk.23.ffn_up.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  214:           blk.23.ffn_down.weight q4_0     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  215:          blk.23.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  216:           blk.23.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  217:             blk.24.attn_q.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  218:             blk.24.attn_k.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  219:             blk.24.attn_v.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  220:        blk.24.attn_output.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  221:           blk.24.ffn_gate.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  222:             blk.24.ffn_up.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  223:           blk.24.ffn_down.weight q4_0     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  224:          blk.24.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  225:           blk.24.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  226:             blk.25.attn_q.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  227:             blk.25.attn_k.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  228:             blk.25.attn_v.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  229:        blk.25.attn_output.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  230:           blk.25.ffn_gate.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  231:             blk.25.ffn_up.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  232:           blk.25.ffn_down.weight q4_0     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  233:          blk.25.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  234:           blk.25.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  235:             blk.26.attn_q.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  236:             blk.26.attn_k.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  237:             blk.26.attn_v.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  238:        blk.26.attn_output.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  239:           blk.26.ffn_gate.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  240:             blk.26.ffn_up.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  241:           blk.26.ffn_down.weight q4_0     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  242:          blk.26.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  243:           blk.26.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  244:             blk.27.attn_q.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  245:             blk.27.attn_k.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  246:             blk.27.attn_v.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  247:        blk.27.attn_output.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  248:           blk.27.ffn_gate.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  249:             blk.27.ffn_up.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  250:           blk.27.ffn_down.weight q4_0     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  251:          blk.27.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  252:           blk.27.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  253:             blk.28.attn_q.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  254:             blk.28.attn_k.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  255:             blk.28.attn_v.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  256:        blk.28.attn_output.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  257:           blk.28.ffn_gate.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  258:             blk.28.ffn_up.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  259:           blk.28.ffn_down.weight q4_0     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  260:          blk.28.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  261:           blk.28.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  262:             blk.29.attn_q.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  263:             blk.29.attn_k.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  264:             blk.29.attn_v.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  265:        blk.29.attn_output.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  266:           blk.29.ffn_gate.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  267:             blk.29.ffn_up.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  268:           blk.29.ffn_down.weight q4_0     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  269:          blk.29.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  270:           blk.29.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  271:             blk.30.attn_q.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  272:             blk.30.attn_k.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  273:             blk.30.attn_v.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  274:        blk.30.attn_output.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  275:           blk.30.ffn_gate.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  276:             blk.30.ffn_up.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  277:           blk.30.ffn_down.weight q4_0     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  278:          blk.30.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  279:           blk.30.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  280:             blk.31.attn_q.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  281:             blk.31.attn_k.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  282:             blk.31.attn_v.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  283:        blk.31.attn_output.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  284:           blk.31.ffn_gate.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  285:             blk.31.ffn_up.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  286:           blk.31.ffn_down.weight q4_0     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  287:          blk.31.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  288:           blk.31.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  289:             blk.32.attn_q.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  290:             blk.32.attn_k.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  291:             blk.32.attn_v.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  292:        blk.32.attn_output.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  293:           blk.32.ffn_gate.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  294:             blk.32.ffn_up.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  295:           blk.32.ffn_down.weight q4_0     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  296:          blk.32.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  297:           blk.32.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  298:             blk.33.attn_q.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  299:             blk.33.attn_k.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  300:             blk.33.attn_v.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  301:        blk.33.attn_output.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  302:           blk.33.ffn_gate.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  303:             blk.33.ffn_up.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  304:           blk.33.ffn_down.weight q4_0     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  305:          blk.33.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  306:           blk.33.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  307:             blk.34.attn_q.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  308:             blk.34.attn_k.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  309:             blk.34.attn_v.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  310:        blk.34.attn_output.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  311:           blk.34.ffn_gate.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  312:             blk.34.ffn_up.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  313:           blk.34.ffn_down.weight q4_0     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  314:          blk.34.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  315:           blk.34.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  316:             blk.35.attn_q.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  317:             blk.35.attn_k.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  318:             blk.35.attn_v.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  319:        blk.35.attn_output.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  320:           blk.35.ffn_gate.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  321:             blk.35.ffn_up.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  322:           blk.35.ffn_down.weight q4_0     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  323:          blk.35.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  324:           blk.35.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  325:             blk.36.attn_q.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  326:             blk.36.attn_k.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  327:             blk.36.attn_v.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  328:        blk.36.attn_output.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  329:           blk.36.ffn_gate.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  330:             blk.36.ffn_up.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  331:           blk.36.ffn_down.weight q4_0     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  332:          blk.36.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  333:           blk.36.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  334:             blk.37.attn_q.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  335:             blk.37.attn_k.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  336:             blk.37.attn_v.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  337:        blk.37.attn_output.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  338:           blk.37.ffn_gate.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  339:             blk.37.ffn_up.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  340:           blk.37.ffn_down.weight q4_0     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  341:          blk.37.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  342:           blk.37.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  343:             blk.38.attn_q.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  344:             blk.38.attn_k.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  345:             blk.38.attn_v.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  346:        blk.38.attn_output.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  347:           blk.38.ffn_gate.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  348:             blk.38.ffn_up.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  349:           blk.38.ffn_down.weight q4_0     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  350:          blk.38.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  351:           blk.38.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  352:             blk.39.attn_q.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  353:             blk.39.attn_k.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  354:             blk.39.attn_v.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  355:        blk.39.attn_output.weight q4_0     [  5120,  5120,     1,     1 ]
# llama_model_loader: - tensor  356:           blk.39.ffn_gate.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  357:             blk.39.ffn_up.weight q4_0     [  5120, 13824,     1,     1 ]
# llama_model_loader: - tensor  358:           blk.39.ffn_down.weight q4_0     [ 13824,  5120,     1,     1 ]
# llama_model_loader: - tensor  359:          blk.39.attn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  360:           blk.39.ffn_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  361:               output_norm.weight f32      [  5120,     1,     1,     1 ]
# llama_model_loader: - tensor  362:                    output.weight q6_K     [  5120, 32032,     1,     1 ]
# llama_model_loader: - kv   0:                       general.architecture str
# llama_model_loader: - kv   1:                               general.name str
# llama_model_loader: - kv   2:                       llama.context_length u32
# llama_model_loader: - kv   3:                     llama.embedding_length u32
# llama_model_loader: - kv   4:                          llama.block_count u32
# llama_model_loader: - kv   5:                  llama.feed_forward_length u32
# llama_model_loader: - kv   6:                 llama.rope.dimension_count u32
# llama_model_loader: - kv   7:                 llama.attention.head_count u32
# llama_model_loader: - kv   8:              llama.attention.head_count_kv u32
# llama_model_loader: - kv   9:     llama.attention.layer_norm_rms_epsilon f32
# llama_model_loader: - kv  10:                          general.file_type u32
# llama_model_loader: - kv  11:                       tokenizer.ggml.model str
# llama_model_loader: - kv  12:                      tokenizer.ggml.tokens arr
# llama_model_loader: - kv  13:                      tokenizer.ggml.scores arr
# llama_model_loader: - kv  14:                  tokenizer.ggml.token_type arr
# llama_model_loader: - kv  15:                tokenizer.ggml.bos_token_id u32
# llama_model_loader: - kv  16:                tokenizer.ggml.eos_token_id u32
# llama_model_loader: - kv  17:            tokenizer.ggml.unknown_token_id u32
# llama_model_loader: - kv  18:               general.quantization_version u32
# llama_model_loader: - type  f32:   81 tensors
# llama_model_loader: - type q4_0:  281 tensors
# llama_model_loader: - type q6_K:    1 tensors
# llm_load_print_meta: format           = GGUF V2 (latest)
# llm_load_print_meta: arch             = llama
# llm_load_print_meta: vocab type       = SPM
# llm_load_print_meta: n_vocab          = 32032
# llm_load_print_meta: n_merges         = 0
# llm_load_print_meta: n_ctx_train      = 4096
# llm_load_print_meta: n_embd           = 5120
# llm_load_print_meta: n_head           = 40
# llm_load_print_meta: n_head_kv        = 40
# llm_load_print_meta: n_layer          = 40
# llm_load_print_meta: n_rot            = 128
# llm_load_print_meta: n_gqa            = 1
# llm_load_print_meta: f_norm_eps       = 0.0e+00
# llm_load_print_meta: f_norm_rms_eps   = 1.0e-05
# llm_load_print_meta: n_ff             = 13824
# llm_load_print_meta: freq_base_train  = 10000.0
# llm_load_print_meta: freq_scale_train = 1
# llm_load_print_meta: model type       = 13B
# llm_load_print_meta: model ftype      = mostly Q4_0
# llm_load_print_meta: model params     = 13.02 B
# llm_load_print_meta: model size       = 6.86 GiB (4.53 BPW)
# llm_load_print_meta: general.name   = LLaMA v2
# llm_load_print_meta: BOS token = 1 '<s>'
# llm_load_print_meta: EOS token = 2 '</s>'
# llm_load_print_meta: UNK token = 0 '<unk>'
# llm_load_print_meta: LF token  = 13 '<0x0A>'
# llm_load_tensors: ggml ctx size =    0.12 MB
# llm_load_tensors: mem required  = 7024.23 MB
# ...................................................................................................
# llama_new_context_with_model: n_ctx      = 2048
# llama_new_context_with_model: freq_base  = 10000.0
# llama_new_context_with_model: freq_scale = 1
# llama_new_context_with_model: kv self size  = 1600.00 MB
# llama_new_context_with_model: compute buffer total size = 199.88 MB

# %%
info_to_add = " The glue is at the position 45.45.679"



llm_agent.add_info_to_mem(info_to_add)
# Out:
#  ' The glue is at the position 45.45.679' was added to the memory

# %%
user_text_request = " what is the position of  the glue"

bot_text_response = llm_agent.memory_response_retriver(user_text_request)
# Out:
# Number of requested results 3 is greater than number of elements in index 2, updating n_results = 2

# %%
type(bot_text_response)
# Out:
# dict

# %%
bot_text_response['choices'][0]['text']
# bot_text_response
# Out:
# ' ME MEMORY CHUNK 1:'

# %%
bot_text_response
# Out:
# {'id': 'cmpl-6dd9a1bc-1f49-413c-b9a1-ebbfff0b6057',
#  'object': 'text_completion',
#  'created': 1706065205,
#  'model': 'nous-hermes-llama2-13b.Q4_0.gguf',
#  'choices': [{'text': 'MEMORY CHUNK 3:  The cheese is at the position 14.45.679\nMEMORY CHUNK 4:  The peanut butter is at the position 14.45.679',
#    'index': 0,
#    'logprobs': None,
#    'finish_reason': 'stop'}],
#  'usage': {'prompt_tokens': 235, 'completion_tokens': 58, 'total_tokens': 293}}

# %% [markdown]
# # Memory.py

# %%
################################################################### Utils
import numpy as np
from functools import wraps
from termcolor import colored


def cosine_similarity(a: np.ndarray, b: np.ndarray):
    return np.dot(a, b.T) / (np.linalg.norm(a) * np.linalg.norm(b))




def logging(enabled = True, message = "", color = "yellow"):
    def decorator(func):
        @wraps(func)
        def wrapper(*args, **kwargs):
            if enabled:
                print(f"LOG: {colored(message, color = color)}")
            return func(*args, **kwargs)
        return wrapper
    return decorator



################################################################ Embeddings

import torch
import os
import numpy as np
from transformers import AutoModel, AutoTokenizer
from chromadb import EmbeddingFunction
from gpt4all import Embed4All
# from dotenv import dotenv_values

# env = dotenv_values(".env")
# os.environ['HUGGINGFACE_HUB_CACHE'] = env['HUGGINGFACE_HUB_CACHE']



class BaseEmbedder(EmbeddingFunction):
    def __init__(self):
        pass

    def get_embeddings(self, texts):
        raise NotImplementedError("Subclasses should implement this!")

    def __call__(self, text):
        return self.get_embeddings(text)


class GPT4AllEmbedder(BaseEmbedder):
    def __init__(self):
        self.embedder = Embed4All() # default: all-MiniLM-L6-v2

    def get_embeddings(self, texts):
        if type(texts) == str:
            texts = [texts]
        
        embeddings = []
        for text in texts:
            embeddings.append(self.embedder.embed(text))

        return embeddings

    def __call__(self, text):
        return self.get_embeddings(text)



################################################################### VectDB
import chromadb
import uuid
import datetime
# from embedder import BaseEmbedder, HFEmbedder
# from dotenv import dotenv_values

# env = dotenv_values(".env")
# DB_PATH = env["DB_PATH"]
DB_PATH = './'

class CollectionOperator():
    def __init__(self, collection_name, db_path = DB_PATH, embedder: BaseEmbedder = None):
        self.embedder = embedder
        self.client = chromadb.PersistentClient(path = db_path)
        self.collection = self.client.get_or_create_collection(name = collection_name, embedding_function = self.embedder.get_embeddings)

    def add(self, text, metadata = {}):
        metadata['timestamp'] = str(datetime.datetime.now())

        self.collection.add(
            documents = [text],
            metadatas = [metadata],
            ids = [str(uuid.uuid4())]
        )

    def delete(self, id):
        self.collection.delete(id)

    def query(self, query, n_results, return_text = True):
        query = self.collection.query(
            query_texts = query,
            n_results = n_results,
        )

        if return_text:
            return query['documents'][0]
        else:
            return query




######################################################################### new llm

from typing import List, Optional, Any
from gpt4all import GPT4All
from llama_cpp import Llama

class BaseLLM():
    def __init__(self, model_name: Optional[str] = None, model_path: Optional[str] = None) -> None:

        self.user = '''We have a database that serves as the memory of a robot. This memory is used by the robot to provide relevant and highly accurate 
        information to solve tasks or answer questions. Your goal is to analyze the information in the memory and assist the robot in providing the most 
        relevant information to solve the task.'''

        self.assistant = '''
        Here are the rules you should follow explicitly: 
        Rules: 
        1 - If there is no relevant information in the memory to answer the question, you must answer with "No relevant information."
        2 - You are not allowed to use any information outside of the provided memory to answer the question.
        
        Remember: There might be cases where the information from the memory is not relevant to solve the task. In such cases, you should explicitly answer 
        with "No relevant information."
        
        Your Response:'''
        self.input = "Here are the pieces of information from the memory:"
        self.streaming = False

        ##############
        self.memory_context = lambda question: f""" 
        Here is the task  \n 
        Task: {question} \n
        """
        ##############

    def generate(self, request: str, streaming: bool) -> Any:
        raise NotImplementedError

    def response(self, request: str) -> Any:
        user = "Instruction" 
        self.assistant = " Response" #"ASSISTANT"
        return self.generate(f"{user}:\n{request}\n{assistant}:\n", streaming = self.streaming)

    ############################################################################################################################
    def memory_response(self, request: str, memory_queries: List[str]) -> Any:
        queries = f"{self.user}:\n{self.memory_context(request)}\n{self.input}:\n"


        for i, query in enumerate(memory_queries):
            queries += f"MEMORY CHUNK {i}: {query}\n"

        queries += f"{self.assistant}:\n"

        return self.generate(queries, streaming = self.streaming)
    ############################################################################################################################

class GPT4AllLLM(BaseLLM):
    def __init__(self, model_name: Optional[str] = None, model_path: Optional[str] = None) -> None:
        super().__init__(model_name, model_path)
        
        self.gpt = GPT4All(model_name = model_name, model_path = model_path, verbose=False)

    def generate(self, request: str, streaming: bool) -> Any:
        return self.gpt.generate(prompt = request, streaming = streaming)

class LlamaCPPLLM(BaseLLM):
    def __init__(self, model_name: Optional[str] = None) -> None:
        super().__init__(model_name)
        
        self.gpt = Llama(model_path = model_name, n_ctx=2048, verbose=False)

    def generate(self, request: str, streaming: bool) -> Any:
        return self.gpt.create_completion(prompt = request, stream = streaming, stop=[f"{self.user}:"])



######################################################################### summarizer


import os
import torch
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
from transformers import pipeline
from dotenv import dotenv_values

checkpoint = "sshleifer/distilbart-cnn-12-6"

class Summarizer():
    def __init__(self, model = checkpoint) -> None:
        self.device = 'cuda' if torch.cuda.is_available() else 'cpu'
        self.model = AutoModelForSeq2SeqLM.from_pretrained(model).to(self.device)
        self.tokenizer = AutoTokenizer.from_pretrained(model)


    def summarize(self, text: str, min_length = 30, max_length = 100):
        """Fixed-size chunking"""
        inputs_no_trunc = self.tokenizer(text, max_length=None, return_tensors='pt', truncation=False)
        if len(inputs_no_trunc['input_ids'][0]) < 30:
            return text

        # min_length = min_length_ratio * len(inputs)
        # max_length = max_length_ratio * len(inputs)
        
        inputs_batch_lst = []
        chunk_start = 0
        chunk_end = self.tokenizer.model_max_length  # == 1024 for Bart
        while chunk_start <= len(inputs_no_trunc['input_ids'][0]):
            inputs_batch = inputs_no_trunc['input_ids'][0][chunk_start:chunk_end]  # get batch of n tokens
            inputs_batch = torch.unsqueeze(inputs_batch, 0)
            inputs_batch_lst.append(inputs_batch)
            chunk_start += self.tokenizer.model_max_length  # == 1024 for Bart
            chunk_end += self.tokenizer.model_max_length  # == 1024 for Bart
        summary_ids_lst = [self.model.generate(inputs.to(self.device), num_beams=4, min_length=min_length, max_length=max_length, early_stopping=True) for inputs in inputs_batch_lst]

        summary_batch_lst = []
        for summary_id in summary_ids_lst:
            summary_batch = [self.tokenizer.decode(g, skip_special_tokens=True, clean_up_tokenization_spaces=False) for g in summary_id]
            summary_batch_lst.append(summary_batch[0])
        summary_all = '\n'.join(summary_batch_lst)

        return summary_all

    def __call__(self, text, min_length = 30, max_length = 100):
        return self.summarize(text, min_length, max_length)

######################################################################### llm Agent

enable_logging = True

class LLMAgent():
    def __init__(
        self, 
        llm: BaseLLM = None, 
        tm_qdb: CollectionOperator = None, 
        summarizer: Summarizer = None, 
        # search_engine: SearchEngine = None,
        use_summarizer = True,
       
    ) -> None:

        self.llm = llm
        self.tm_qdb = tm_qdb
        self.memory_access_threshold = 1.5
        # self.similarity_threshold = 0.5 # [0; 1]
        self.db_n_results = 3
        self.se_n_results = 3
        self.use_summarizer = use_summarizer
       
        self.summarizer = summarizer
        # self.search_engine = search_engine
       

    @logging(enable_logging, message = "[Adding to memory]")
    def add(self, request):
        
        summary = self.summarize(request) if self.use_summarizer else request

        self.tm_qdb.add(summary) if summary != "" else None

        response = self.llm.response(request)

        return response
        
    ###################################### New Info to Memory without chat
    
    def add_info_to_mem(self, request):
        # summary = self.summarizer(f"{self.llm.user}:\n{request}\n{self.llm.assistant}:\n{''.join(response)}")
        
        summary = self.summarize(request) if self.use_summarizer else request

        self.tm_qdb.add(summary) if summary != "" else None
        print(f" '{summary}' was added to the memory")

        # response = self.llm.response(request)

    
     ###################################### Get response without chat #####

    
    def memory_response_retriver(self, request):
        memory_queries_data = self.tm_qdb.query(request, n_results = self.db_n_results, return_text = False)
        memory_queries = memory_queries_data['documents'][0]
        memory_queries_distances = memory_queries_data['distances'][0]
    
        acceptable_memory_queries = []
    
        for query, distance in list(zip(memory_queries, memory_queries_distances)):
            # print(f"Query: {query}, Distance: {distance}")
            if distance < self.memory_access_threshold:
            # if (1 - distance) >= self.similarity_threshold:
                acceptable_memory_queries.append(query)
    
        if len(acceptable_memory_queries) > 0:
            response = self.llm.memory_response(request, acceptable_memory_queries)
        else:
            # response = self.llm.response(request) #TODO: add another solution
            response  = "No relevant information."    
        return response
        

    ############################################################################################################################
    @logging(enable_logging, message = "[Querying memory]")
    def memory_response(self, request):
        memory_queries_data = self.tm_qdb.query(request, n_results = self.db_n_results, return_text = False)
        memory_queries = memory_queries_data['documents'][0]
        memory_queries_distances = memory_queries_data['distances'][0]

        acceptable_memory_queries = []

        for query, distance in list(zip(memory_queries, memory_queries_distances)):
            # print(f"Query: {query}, Distance: {distance}")
            if distance < self.memory_access_threshold:
            # if (1 - distance) >= self.similarity_threshold:
                acceptable_memory_queries.append(query)

        if len(acceptable_memory_queries) > 0:
            response = self.llm.memory_response(request, acceptable_memory_queries)
        else:
            response = self.llm.response(request) #TODO: add another solution

        return response
    ############################################################################################################################

    @logging(enable_logging, message = "[Summarizing]", color = "green")
    def summarize(self, text, min_length = 30, max_length = 100):
        return self.summarizer(text, min_length, max_length)


    @logging(enable_logging, message = "[Response]")
    def response(self, request):
        return self.llm.response(request)

    
    def generate(self, request: str):
        if request.upper().startswith("MEM"):
            response = self.memory_response(request[len("MEM"):])
        elif request.upper().startswith("REMEM"): #and len(acceptable_memory_queries) == 0
            response = self.add(request[len("REMEM"):])
        # elif request.upper().startswith("WEB"):
        #     response = self.search(request[len("WEB"):])
        else:
            response = self.response(request)
            
        return response

# %% [markdown]
# # On Server

# %%
from flask import Flask, request


################################################################### Utils
import numpy as np
from functools import wraps
from termcolor import colored


def cosine_similarity(a: np.ndarray, b: np.ndarray):
    return np.dot(a, b.T) / (np.linalg.norm(a) * np.linalg.norm(b))




def logging(enabled = True, message = "", color = "yellow"):
    def decorator(func):
        @wraps(func)
        def wrapper(*args, **kwargs):
            if enabled:
                print(f"LOG: {colored(message, color = color)}")
            return func(*args, **kwargs)
        return wrapper
    return decorator



################################################################ Embeddings

import torch
import os
import numpy as np
from transformers import AutoModel, AutoTokenizer
from chromadb import EmbeddingFunction
from gpt4all import Embed4All
# from dotenv import dotenv_values

# env = dotenv_values(".env")
# os.environ['HUGGINGFACE_HUB_CACHE'] = env['HUGGINGFACE_HUB_CACHE']



class BaseEmbedder(EmbeddingFunction):
    def __init__(self):
        pass

    def get_embeddings(self, texts):
        raise NotImplementedError("Subclasses should implement this!")

    def __call__(self, text):
        return self.get_embeddings(text)


class GPT4AllEmbedder(BaseEmbedder):
    def __init__(self):
        self.embedder = Embed4All() # default: all-MiniLM-L6-v2

    def get_embeddings(self, texts):
        if type(texts) == str:
            texts = [texts]
        
        embeddings = []
        for text in texts:
            embeddings.append(self.embedder.embed(text))

        return embeddings

    def __call__(self, text):
        return self.get_embeddings(text)
    

class HFEmbedder(BaseEmbedder):
    # def __init__(self, model = 'princeton-nlp/sup-simcse-roberta-large'): #sentence-transformers/all-MiniLM-L6-v2 
    def __init__(self, model = '/app/weights/sup-simcse-roberta-large'):
        self.device = 'cuda' if torch.cuda.is_available() else 'cpu'
        self.model = AutoModel.from_pretrained(model).to(self.device)
        self.tokenizer = AutoTokenizer.from_pretrained(model)
        

    def get_embeddings(self, texts):
        if type(texts) == str:
            texts = [texts]

        inputs = self.tokenizer(texts, padding=True, truncation=True, return_tensors="pt").to(self.device)

        with torch.no_grad():
            embeddings = self.model(**inputs, output_hidden_states=True, return_dict=True).pooler_output.detach().cpu().numpy()

        norms = np.linalg.norm(embeddings, axis=1, keepdims=True)
        normalized_embeddings = embeddings / norms

        return normalized_embeddings.tolist()

    def __call__(self, text):
        return self.get_embeddings(text)




################################################################### VectDB
import chromadb
import uuid
import datetime
# from embedder import BaseEmbedder, HFEmbedder
# from dotenv import dotenv_values

# env = dotenv_values(".env")
# DB_PATH = env["DB_PATH"]
DB_PATH = './'

class CollectionOperator():
    def __init__(self, collection_name, db_path = DB_PATH, embedder: BaseEmbedder = None):
        self.embedder = embedder
        self.client = chromadb.PersistentClient(path = db_path)
        self.collection = self.client.get_or_create_collection(name = collection_name, embedding_function = self.embedder.get_embeddings)

    def add(self, text, metadata = {}):
        metadata['timestamp'] = str(datetime.datetime.now())

        self.collection.add(
            documents = [text],
            metadatas = [metadata],
            ids = [str(uuid.uuid4())]
        )

    def delete(self, id):
        self.collection.delete(id)

    def query(self, query, n_results, return_text = True):
        query = self.collection.query(
            query_texts = query,
            n_results = n_results,
        )

        if return_text:
            return query['documents'][0]
        else:
            return query




######################################################################### new llm

from typing import List, Optional, Any
from gpt4all import GPT4All
from llama_cpp import Llama

class BaseLLM():
    def __init__(self, model_name: Optional[str] = None, model_path: Optional[str] = None) -> None:

        self.user = """
            I will provide you with MEMORY CHUNKs retrieved from a database. Your goal is to use these MEMORY CHUNKs to solve a task or answer a question. 
            Rely solely on the information from the MEMORY CHUNKs for solving the task or responding to the query.
            """

       self.assistant = """
        Please adhere to these essential rules when formulating your responses:
        
        Rule 1: If the MEMORY CHUNKs do not contain relevant information to solve the task or answer the question, respond explicitly with "None".
        Rule 2: Do not use any information beyond what is provided in the MEMORY CHUNKs.
        Rule 3: In cases where the MEMORY CHUNKs' information is irrelevant to the task, respond explicitly with "None".
        Rule 4: Provide a direct answer to the question without any additional commentary.
        """
        self.input = "Utilize the following MEMORY CHUNKs explicitly:"
        self.streaming = False

        ##############
        self.memory_context = lambda question: f""" 
        Here is the task  
        Task: {question} 
        """
        ##############

    def generate(self, request: str, streaming: bool) -> Any:
        raise NotImplementedError

    def response(self, request: str) -> Any:
        user = "Instruction" 
        self.assistant = " Response" 
        return self.generate(f"{user}:\n{request}\n{assistant}:\n", streaming = self.streaming)

    ############################################################################################################################
    # def memory_response(self, request: str, memory_queries: List[str]) -> Any:
    #     queries = f"{self.user}:\n{self.memory_context(request)}\n{self.input}:\n"


    #     for i, query in enumerate(memory_queries):
    #         queries += f"MEMORY CHUNK {i}: {query}\n"

    #     queries += f"{self.assistant}:\n"

    #     return self.generate(queries, streaming = self.streaming)

    def memory_response(self, request: str, memory_queries: List[str]) -> Any:
        queries = f"{self.user}\n{self.assistant}\n{self.memory_context(request)}\n{self.input}:\n"


        for i, query in enumerate(memory_queries):
            queries += f"MEMORY CHUNK {i}: {query}\n"

        queries = queries.replace('\n', '')

        return self.generate(queries, streaming = self.streaming)
    ############################################################################################################################

class GPT4AllLLM(BaseLLM):
    def __init__(self, model_name: Optional[str] = None, model_path: Optional[str] = None) -> None:
        super().__init__(model_name, model_path)
        
        self.gpt = GPT4All(model_name = model_name, model_path = model_path, verbose=False)

    def generate(self, request: str, streaming: bool) -> Any:
        return self.gpt.generate(prompt = request, streaming = streaming)

class LlamaCPPLLM(BaseLLM):
    def __init__(self, model_name: Optional[str] = None) -> None:
        super().__init__(model_name)
        
        self.gpt = Llama(model_path = model_name, n_ctx=2048, verbose=False)

    def generate(self, request: str, streaming: bool) -> Any:
        return self.gpt.create_completion(prompt = request, stream = streaming, stop=[f"{self.user}:"])



######################################################################### summarizer


import os
import torch
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
from transformers import pipeline
from dotenv import dotenv_values

checkpoint = "sshleifer/distilbart-cnn-12-6"

class Summarizer():
    def __init__(self, model = checkpoint) -> None:
        self.device = 'cuda' if torch.cuda.is_available() else 'cpu'
        self.model = AutoModelForSeq2SeqLM.from_pretrained(model).to(self.device)
        self.tokenizer = AutoTokenizer.from_pretrained(model)


    def summarize(self, text: str, min_length = 30, max_length = 100):
        """Fixed-size chunking"""
        inputs_no_trunc = self.tokenizer(text, max_length=None, return_tensors='pt', truncation=False)
        if len(inputs_no_trunc['input_ids'][0]) < 30:
            return text

        # min_length = min_length_ratio * len(inputs)
        # max_length = max_length_ratio * len(inputs)
        
        inputs_batch_lst = []
        chunk_start = 0
        chunk_end = self.tokenizer.model_max_length  # == 1024 for Bart
        while chunk_start <= len(inputs_no_trunc['input_ids'][0]):
            inputs_batch = inputs_no_trunc['input_ids'][0][chunk_start:chunk_end]  # get batch of n tokens
            inputs_batch = torch.unsqueeze(inputs_batch, 0)
            inputs_batch_lst.append(inputs_batch)
            chunk_start += self.tokenizer.model_max_length  # == 1024 for Bart
            chunk_end += self.tokenizer.model_max_length  # == 1024 for Bart
        summary_ids_lst = [self.model.generate(inputs.to(self.device), num_beams=4, min_length=min_length, max_length=max_length, early_stopping=True) for inputs in inputs_batch_lst]

        summary_batch_lst = []
        for summary_id in summary_ids_lst:
            summary_batch = [self.tokenizer.decode(g, skip_special_tokens=True, clean_up_tokenization_spaces=False) for g in summary_id]
            summary_batch_lst.append(summary_batch[0])
        summary_all = '\n'.join(summary_batch_lst)

        return summary_all

    def __call__(self, text, min_length = 30, max_length = 100):
        return self.summarize(text, min_length, max_length)

######################################################################### llm Agent

enable_logging = True

class LLMAgent():
    def __init__(
        self, 
        llm: BaseLLM = None, 
        tm_qdb: CollectionOperator = None, 
        summarizer: Summarizer = None, 
        # search_engine: SearchEngine = None,
        use_summarizer = True,
       
    ) -> None:

        self.llm = llm
        self.tm_qdb = tm_qdb
        self.memory_access_threshold = 1.5
        # self.similarity_threshold = 0.5 # [0; 1]
        self.db_n_results = 3
        self.se_n_results = 3
        self.use_summarizer = use_summarizer
       
        self.summarizer = summarizer
        # self.search_engine = search_engine
       

    @logging(enable_logging, message = "[Adding to memory]")
    def add(self, request):
        
        summary = self.summarize(request) if self.use_summarizer else request

        self.tm_qdb.add(summary) if summary != "" else None

        response = self.llm.response(request)

        return response
        
    ###################################### New Info to Memory without chat
    
    def add_info_to_mem(self, request):
        # summary = self.summarizer(f"{self.llm.user}:\n{request}\n{self.llm.assistant}:\n{''.join(response)}")
        
        summary = self.summarize(request) if self.use_summarizer else request

        self.tm_qdb.add(summary) if summary != "" else None
        print(f" '{summary}' was added to the memory")

        # response = self.llm.response(request)

    
     ###################################### Get response without chat #####

    
    def memory_response_retriver(self, request):
        memory_queries_data = self.tm_qdb.query(request, n_results = self.db_n_results, return_text = False)
        memory_queries = memory_queries_data['documents'][0]
        memory_queries_distances = memory_queries_data['distances'][0]
    
        acceptable_memory_queries = []
    
        for query, distance in list(zip(memory_queries, memory_queries_distances)):
            # print(f"Query: {query}, Distance: {distance}")
            if distance < self.memory_access_threshold:
            # if (1 - distance) >= self.similarity_threshold:
                acceptable_memory_queries.append(query)
    
        if len(acceptable_memory_queries) > 0:
            response = self.llm.memory_response(request, acceptable_memory_queries)
        else:
            # response = self.llm.response(request) #TODO: add another solution
            response  = "None"    
        return response
        

    ############################################################################################################################
    @logging(enable_logging, message = "[Querying memory]")
    def memory_response(self, request):
        memory_queries_data = self.tm_qdb.query(request, n_results = self.db_n_results, return_text = False)
        memory_queries = memory_queries_data['documents'][0]
        memory_queries_distances = memory_queries_data['distances'][0]

        acceptable_memory_queries = []

        for query, distance in list(zip(memory_queries, memory_queries_distances)):
            # print(f"Query: {query}, Distance: {distance}")
            if distance < self.memory_access_threshold:
            # if (1 - distance) >= self.similarity_threshold:
                acceptable_memory_queries.append(query)

        if len(acceptable_memory_queries) > 0:
            response = self.llm.memory_response(request, acceptable_memory_queries)
        else:
            response = self.llm.response(request) #TODO: add another solution

        return response
    ############################################################################################################################

    @logging(enable_logging, message = "[Summarizing]", color = "green")
    def summarize(self, text, min_length = 30, max_length = 100):
        return self.summarizer(text, min_length, max_length)


    @logging(enable_logging, message = "[Response]")
    def response(self, request):
        return self.llm.response(request)

    
    def generate(self, request: str):
        if request.upper().startswith("MEM"):
            response = self.memory_response(request[len("MEM"):])
        elif request.upper().startswith("REMEM"): #and len(acceptable_memory_queries) == 0
            response = self.add(request[len("REMEM"):])
        # elif request.upper().startswith("WEB"):
        #     response = self.search(request[len("WEB"):])
        else:
            response = self.response(request)
            
        return response







#########################################################################################

import os

###############################################################################
# Set the model path
os.environ['LLM_PATH'] = 'nous-hermes-llama2-13b.Q4_0.gguf'

port_lib_name = "LLAMA_CPP"
# port_lib_name = "none"

if port_lib_name == "LLAMA_CPP":
    LLM = LlamaCPPLLM

else:
    LLM = GPT4AllLLM


llm = LLM(os.environ.get('LLM_PATH'))

embedder = HFEmbedder()

summarizer = Summarizer()

total_memory_co = CollectionOperator("total-memory", embedder = embedder)

llm_agent = LLMAgent(llm, total_memory_co, summarizer, use_summarizer = True)




def add_info(info_to_add):
    info_to_add = str(info_to_add)
    llm_agent.add_info_to_mem(info_to_add)

def retrieve_info(user_text_request):
    bot_text_response = llm_agent.memory_response_retriver(user_text_request)  
    if type(bot_text_response)== str:
        return bot_text_response
    else:
        return bot_text_response['choices'][0]['text']

 
#########################################################################################

app = Flask(__name__)

# # Define your functions here
# def add_info(info_to_add):
#     info_to_add = str(info_to_add)
#     llm_agent.add_info_to_mem(info_to_add)

# def retrieve_info(user_text_request):
#     bot_text_response = llm_agent.memory_response_retriever(user_text_request)
#     print(bot_text_response)
#     bot_text_response = dict(bot_text_response)
#     return bot_text_response['choices'][0]['text']

# Define your API endpoints
@app.route('/addinfo', methods=['POST'])
def addinfo():

    data = request.json

    info_to_add = data['info']

    print("info_to_add: " + info_to_add)

    # info_to_add = request.form['info']
    add_info(info_to_add)
    return 'Info added successfully'

@app.route('/retrieveinfo', methods=['POST'])
def retrieveinfo():
    # user_text_request = request.form['text']

    data = request.json

    user_text_request = data['text']

    print("user_text_request: " + user_text_request)

    response = retrieve_info(user_text_request)
    return response

if __name__ == '__main__':
    app.run(host='0.0.0.0', port=7778)

# %% [markdown]
# # Memory Communication.py

# %%
import requests

# Function to add information
def add_info(info_to_add):
    url = "http://192.168.2.185:8004/addinfo"  # Endpoint URL
    data = {"info": info_to_add}  # Request payload
    response = requests.post(url, json=data)  # Send POST request
    if response.status_code == 200:
        print("Info added successfully")
    else:
        print("Failed to add info")

# Function to retrieve information
def retrieve_info(user_text_request):
    url = "http://192.168.2.185:8004/retrieveinfo"  # Endpoint URL
    data = {"text": user_text_request}  # Request payload
    response = requests.post(url, json=data)  # Send POST request
    if response.status_code == 200:
        return response.text
    else:
        return "Failed to retrieve info"

# Usage example (Add at least three info to the DB at the beginning)
add_info("The cola is in the kitchen")
add_info("The robot manipulator is working")
add_info("The apple is red")


print("saved")
response = retrieve_info("where is the  cola")
print(response)
# Out:
# Info added successfully
# Info added successfully
# Info added successfully
# saved
#  and the orange is green

# %%
response
# Out:
# ' and the orange is green'

# %%
        self.user = """
            I will provide you with a text retrieved from a database. Your goal is to use this text to solve a task or answer a question. 
            Rely solely on the information from the provided text for solving the task or responding to the query.
            """

        self.assistant = """
        Please adhere to these essential rules when formulating your responses:
        
        Rule 1: If the text do not contain relevant information to solve the task or answer the question, respond explicitly with "None".
        Rule 2: Do not use any information beyond what is provided in the text.
        Rule 3: In cases where the text information is irrelevant to the task, respond explicitly with "None".
        Rule 4: Provide a direct answer to the question without any additional commentary.
        """
        self.input = "Utilize the following text explicitly:"
        self.streaming = False

        ##############
        self.memory_context = lambda question: f""" 
        Here is the task  
        Task: {question} 
        """

# %%
self.user = """
    You will be given a text extracted from a database. Your objective is to utilize this text exclusively to address a task or answer a question. 
    Depend solely on the provided text for resolution or response.
    """

self.assistant = """
    Adhere strictly to the following rules when crafting your responses:
    
    Rule 1: If the provided text lacks relevant information to resolve the task or answer the question, clearly respond with "None".
    Rule 2: Refrain from incorporating any information outside of the provided text.
    Rule 3: Should the information in the text be irrelevant to the task, explicitly respond with "None".
    Rule 4: Offer a straightforward answer to the question, omitting any supplementary comments.
    """
self.input = "Here is the text extracted from a database:"
self.streaming = False

##############
self.memory_context = lambda question: f""" 
Here's your task:  
Task: {question} 
"""
